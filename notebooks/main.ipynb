# %%
#config 
import os 
import sys
root_path = os.path.abspath('..')
if root_path not in sys.path:
    sys.path.insert(0, root_path)
script_path=os.path.abspath(os.path.join('..', 'scripts'))
if script_path not in sys.path:
    sys.path.append(script_path)

# %%
# import all libaries 
from scripts.libraries import *;

# %%
#load all data
benin_data_set=DataFrameLoader("../data/benin-malanville.csv").load()
sierraleone_data_set=DataFrameLoader("../data/sierraleone-bumbuna.csv").load()
togo_data_set=DataFrameLoader("../data/togo-dapaong_qc.csv").load()

# %%
#data summary 
from scripts.data_summary import DataSummary
DataSummary(benin_data_set).summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 2
#       1 #data summary
# ----> 2 DataSummary(benin_data_set).summary()
#
# NameError: name 'DataSummary' is not defined

# %%
# benin_data_set.describe()
# from scripts.dataframe_null_cols import DataFrameNullCols
print(DataFrameNullCols(benin_data_set).columns_with_nulls())
print(DataFrameNullCols(sierraleone_data_set).columns_with_nulls())
print(DataFrameNullCols(togo_data_set).columns_with_nulls())

# benin_data_set.isnull().sum()
# sierraleone_data_set.isnull().sum()
benin_data_set.isnull().sum()

# sns.boxenplot(benin_data_set['ModB'])
# Out:
# ['Comments']
# ['Comments']
# ['Comments']
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
benin_data_set.describe()
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# ...

# %%
from scripts.heatmap import HeatMap
benin_data_set_comment_removed=benin_data_set.drop(columns=['Comments'])
HeatMap(benin_data_set_comment_removed).plot_heatmap()
# .plot_heatmap()
# correlation_matrix=benin_data_set_comment_removed.corr()
# plt.figure(figsize=(20, 10))
# sns.heatmap(correlation_matrix, annot=True)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 3
#       1 from scripts.heatmap import HeatMap
#       2 benin_data_set_comment_removed=benin_data_set.drop(columns=['Comments'])
# ----> 3 HeatMap(benin_data_set_comment_removed).plot_heatmap()
#       4 # .plot_heatmap()
#       5 # correlation_matrix=benin_data_set_comment_removed.corr()
#       6 # plt.figure(figsize=(20, 10))
#       7 # sns.heatmap(correlation_matrix, annot=True)
#       8 # plt.show()
#
# File d:\Projects\10ac\Solar-Radiation-Measurement\scripts\heatmap.py:9, in HeatMap.plot_heatmap(self)
#       7 def plot_heatmap(self):
#       8     # benin_data_set_comment_removed=benin_data_set.drop(columns=['Comments','Timestamp'])
# ----> 9     correlation_matrix=df.corr()
#      10     plt.figure(figsize=(20, 10))
#      11     sns.heatmap(correlation_matrix, annot=True)
#
# ...

# %% [markdown]
# Summary Statistics of Benin Data Set

# %%
#describe Benin_data
# benin_data_set['GHI']
(benin_data_set['GHI'] < 0).sum()
from scripts.plot import *
# benin_data_set.set_index('Timestamp', inplace=True)
Plot(benin_data_set).plot_line()
sierraleone_data_set.set_index('Timestamp', inplace=True)

Plot(sierraleone_data_set).plot_line()
# Plot(benin_data_set).plot_area()

# %%
benin_data_set.isna()
# Out:
#         Timestamp    GHI    DNI    DHI   ModA   ModB   Tamb     RH     WS  \
# 0           False  False  False  False  False  False  False  False  False
# 1           False  False  False  False  False  False  False  False  False
# 2           False  False  False  False  False  False  False  False  False
# 3           False  False  False  False  False  False  False  False  False
# 4           False  False  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 525595      False  False  False  False  False  False  False  False  False
# 525596      False  False  False  False  False  False  False  False  False
# 525597      False  False  False  False  False  False  False  False  False
# 525598      False  False  False  False  False  False  False  False  False
# 525599      False  False  False  False  False  False  False  False  False
#
#         WSgust  WSstdev     WD  WDstdev     BP  Cleaning  Precipitation  \
# ...

# %%
benin_data_set.plot(kind="box",subplots=True,layout=(18,2),figsize=(20,40))
# Out:
# GHI                 Axes(0.125,0.844019;0.352273x0.0359813)
# DNI              Axes(0.547727,0.844019;0.352273x0.0359813)
# DHI                 Axes(0.125,0.800841;0.352273x0.0359813)
# ModA             Axes(0.547727,0.800841;0.352273x0.0359813)
# ModB                Axes(0.125,0.757664;0.352273x0.0359813)
# Tamb             Axes(0.547727,0.757664;0.352273x0.0359813)
# RH                  Axes(0.125,0.714486;0.352273x0.0359813)
# WS               Axes(0.547727,0.714486;0.352273x0.0359813)
# WSgust              Axes(0.125,0.671308;0.352273x0.0359813)
# WSstdev          Axes(0.547727,0.671308;0.352273x0.0359813)
# WD                  Axes(0.125,0.628131;0.352273x0.0359813)
# WDstdev          Axes(0.547727,0.628131;0.352273x0.0359813)
# BP                  Axes(0.125,0.584953;0.352273x0.0359813)
# Cleaning         Axes(0.547727,0.584953;0.352273x0.0359813)
# Precipitation       Axes(0.125,0.541776;0.352273x0.0359813)
# TModA            Axes(0.547727,0.541776;0.352273x0.0359813)
# ...

# %%
import os
import sys
path=os.path.abspath('..')
print(path)
if path not in sys.path:
        sys.path.insert(0,path)
# sys.path.append(os.path.abspath(os.path.join('..', 'scripts')))        
from scripts.dataframe_loader import DataFrameLoader
# Out:
# d:\Projects\10ac\Solar-Radiation-Measurement

# %%
DataFrameLoader("dsdsh.yu").load()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 DataFrameLoader("dsdsh.yu").load()
#
# File d:\Projects\10ac\Solar-Radiation-Measurement\scripts\dataframe_loader.py:21, in DataFrameLoader.load(self)
#      19     df = pd.read_json(self.file_path)
#      20 else:
# ---> 21     raise ValueError(f"Unsupported file extension: {file_extension}")
#      23 return df
#
# ValueError: Unsupported file extension: .yu
